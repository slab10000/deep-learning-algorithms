# %%
import torch
import numpy as np

# %%
tensor_of_ones = torch.ones(5)
print(tensor_of_ones)
print(tensor_of_ones.shape)
# Out:
# tensor([1., 1., 1., 1., 1.])
# torch.Size([5])

# %%
tensor_of_ones[2] = 1000
print(torch.argmax(tensor_of_ones))
print(tensor_of_ones[torch.argmax(tensor_of_ones)])
# Out:
# tensor(2)
# tensor(1000.)
